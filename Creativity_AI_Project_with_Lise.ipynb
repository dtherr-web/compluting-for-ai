# %% [markdown]
# <a href="https://colab.research.google.com/github/dtherr-web/compluting-for-ai/blob/main/Creativity_AI_Project_with_Lise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is where we'll do our coding and keep track of changes... DT
